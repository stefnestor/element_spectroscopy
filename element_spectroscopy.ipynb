# %% [markdown]
# <a href="https://colab.research.google.com/github/stefnestor/element_spectroscopy/blob/main/element_spectroscopy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for element_name in element:
  e = element[element_name]
  l = len(e)
  for n in e:
    plt.hist(n[0], 1, facecolor=n[1], alpha=0.9)
  plt.hist(380, 1, facecolor="#fff", alpha=0.1)
  plt.hist(780, 1, facecolor="#fff", alpha=0.1)
  plt.title(element_name,rotation='vertical',x=-0.1,y=0.3)
  plt.axis("off")
  plt.show()

# %%
for element_name in element:
  e = element[element_name]
  l = len(e)
  for n in range(l):
    s = e[n]
    plt.subplot(l,1,n+1)
    plt.hist(s[0],1,facecolor=s[1],alpha=.9)
    plt.axis("off")
  plt.title(element_name,rotation='vertical',x=-0.1,y=0)
  plt.axis("off")
  plt.show()
  print("\n\n")
